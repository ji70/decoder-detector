# %%
import os
import random
import shutil
import pandas as pd
import json

# %%
data = pd.read_csv('train.csv')
data.shape
# Out:
# (7357, 63)

# %%
data.head()
# Out:
#    Unnamed: 0 :authority :method :path :scheme  \
# 0           0        NaN     NaN   NaN     NaN
# 1           1        NaN     NaN   NaN     NaN
# 2           2        NaN     NaN   NaN     NaN
# 3           3        NaN     NaN   NaN     NaN
# 4           4        NaN     NaN   NaN     NaN
#
#                                               accept    accept-encoding  \
# 0  text/html,application/xhtml+xml,application/xm...  gzip, deflate, br
# 1                                                NaN                NaN
# 2  text/html,application/xhtml+xml,application/xm...  gzip, deflate, br
# 3                                                NaN                NaN
# 4  text/html,application/xhtml+xml,application/xm...  gzip, deflate, br
#
#                        accept-language adrum                  body  \
# 0  ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7   NaN  state12345=MTg%3D+\n
# 1                                  NaN   NaN  state12345=MzQ%3D+\n
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  content-length  dst_port  google-accounts-xsrf  \
# count  7357.000000     2686.000000    7357.0                   4.0
# mean   3678.000000     3130.495905      80.0                   1.0
# std    2123.927298     4605.620732       0.0                   0.0
# min       0.000000        0.000000      80.0                   1.0
# 25%    1839.000000      351.000000      80.0                   1.0
# 50%    3678.000000     1756.000000      80.0                   1.0
# 75%    5517.000000     3472.500000      80.0                   1.0
# max    7356.000000    38949.000000      80.0                   1.0
#
#            protocol  src_port  upgrade-insecure-requests  uri_fragment  \
# count  7.357000e+03    7357.0                       39.0           0.0
# mean   1.100000e+00   44332.0                        1.0           NaN
# std    1.472256e-13       0.0                        0.0           NaN
# min    1.100000e+00   44332.0                        1.0           NaN
# ...
